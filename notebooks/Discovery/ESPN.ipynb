# %%
import soccerdata as sd     

ESPN = sd.ESPN()

print(ESPN.available_leagues())
# Out:
# [08/31/25 18:31:00] INFO     Saving cached data to /home/manati/soccerdata/data/ESPN                 ]8;id=16658;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=922348;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py#263\263]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=871845;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=143072;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py#475\475]8;;\
# ['ENG-Premier League', 'ESP-La Liga', 'FRA-Ligue 1', 'GER-Bundesliga', 'ITA-Serie A']

# %%
ESPN.read_schedule(season = '16-17')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ESPN.read_schedule(season = '16-17')
#
# TypeError: ESPN.read_schedule() got an unexpected keyword argument 'season'
