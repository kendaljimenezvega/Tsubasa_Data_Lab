# %%
import soccerdata as sd

MH = sd.MatchHistory(leagues= 'ENG-Premier League')
# Out:
# [08/31/25 18:38:02] INFO     Saving cached data to /home/manati/soccerdata/data/MatchHistory         ]8;id=17020;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=875345;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py#263\263]8;;\
#                     INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=22354;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=122156;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py#475\475]8;;\

# %%
MH.available_leagues()
# Out:
# ['ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'ITA-Serie A']

# %%
Df = MH.read_games().head()
# Out:
# [08/31/25 18:50:35] INFO     Parsing league=E0 season=2425                                      ]8;id=1123;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/match_history.py\match_history.py]8;;\:]8;id=516621;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/match_history.py#17\17]8;;\
#                     INFO     Parsing league=E0 season=2324                                      ]8;id=195524;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/match_history.py\match_history.py]8;;\:]8;id=335700;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/match_history.py#17\17]8;;\
# ...

# %%
print(Df.dtypes)
# Out:
# date         datetime64[ns]
# home_team            object
# away_team            object
# FTHG                  int64
# FTAG                  int64
#                   ...
# IWCD                float64
# IWCA                float64
# VCCH                float64
# VCCD                float64
# VCCA                float64
# Length: 130, dtype: object
