# %%
import soccerdata as sd
import pandas as pd
import datetime
import warnings

# Suppress all warnings

# %%
fb = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=2021)

team_match_stats = fb.read_team_match_stats(stat_type='shooting',opponent_stats=False)
team_match_stats.head()
# Out:
# [09/15/25 19:13:04] ERROR    Error while scraping                                                    ]8;id=887841;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=472688;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_common.py#545\545]8;;\
#                              https://fbref.com/en/squads/e2d8892c/2020-2021/matchlogs/all_comps/shoo
#                              ting. Retrying... (attempt 1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerda
#                              ta/_common.py", line 525, in _download_and_save
#                                  response.raise_for_status()
#                                File
#                              "/home/manati/dataproject/dataenv/lib/python3.12/site-packages/requests
#                              /models.py", line 1026, in raise_for_status
#                                  raise HTTPError(http_error_msg, response=self)
#                              requests.exceptions.HTTPError: 500 Server Error: Internal Server Error
#                              for url:
#                              https://fbref.com/en/squads/e2d8892c/2020-2021/matchlogs/all_comps/shoo
#                              ting
#                                                             date  \
#
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés      2020-12-16
#                      2021-01-06 La Coruña-Alavés      2021-01-06
#                      2021-01-16 Almería-Alavés        2021-01-16
#               Angers 2021-02-11 Angers-Rennes         2021-02-11
#                      2021-03-07 Angers-C. Franciscain 2021-03-07
#
#                                                               round  day  \
#
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés        First round  Wed
#                      2021-01-06 La Coruña-Alavés       Second round  Wed
#                      2021-01-16 Almería-Alavés          Round of 32  Sat
#               Angers 2021-02-11 Angers-Rennes           Round of 64  Thu
#                      2021-03-07 Angers-C. Franciscain   Round of 32  Sun
#
#                                                       venue result GF GA  \
#
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés       Away      W  2  0
#                      2021-01-06 La Coruña-Alavés       Away      W  1  0
#                      2021-01-16 Almería-Alavés         Away      L  0  5
#               Angers 2021-02-11 Angers-Rennes          Home      W  2  1
#                      2021-03-07 Angers-C. Franciscain  Home      W  5  0
#
#                                                              opponent  \
#
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés            CD Rincón
#                      2021-01-06 La Coruña-Alavés            La Coruña
#                      2021-01-16 Almería-Alavés                Almería
#               Angers 2021-02-11 Angers-Rennes                  Rennes
#                      2021-03-07 Angers-C. Franciscain  C. Franciscain
#
#                                                       Standard        ...  \
#                                                            Gls    Sh  ...
# league season team   game                                             ...
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés             2  <NA>  ...
#                      2021-01-06 La Coruña-Alavés             1    12  ...
#                      2021-01-16 Almería-Alavés               0    12  ...
#               Angers 2021-02-11 Angers-Rennes                2     7  ...
#                      2021-03-07 Angers-C. Franciscain        5    25  ...
#
#                                                                      Expected  \
#                                                          FK PK PKatt       xG
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés       <NA>  0     0     <NA>
#                      2021-01-06 La Coruña-Alavés       <NA>  0     0     <NA>
#                      2021-01-16 Almería-Alavés         <NA>  0     0     <NA>
#               Angers 2021-02-11 Angers-Rennes          <NA>  1     1     <NA>
#                      2021-03-07 Angers-C. Franciscain  <NA>  0     0     <NA>
#
#                                                                            \
#                                                        npxG npxG/Sh  G-xG
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés       <NA>    <NA>  <NA>
#                      2021-01-06 La Coruña-Alavés       <NA>    <NA>  <NA>
#                      2021-01-16 Almería-Alavés         <NA>    <NA>  <NA>
#               Angers 2021-02-11 Angers-Rennes          <NA>    <NA>  <NA>
#                      2021-03-07 Angers-C. Franciscain  <NA>    <NA>  <NA>
#
#                                                                    time  \
#                                                       np:G-xG
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés         <NA>  21:00:00
#                      2021-01-06 La Coruña-Alavés         <NA>  19:00:00
#                      2021-01-16 Almería-Alavés           <NA>  12:00:00
#               Angers 2021-02-11 Angers-Rennes            <NA>  21:00:00
#                      2021-03-07 Angers-C. Franciscain    <NA>  18:30:00
#
#                                                                                             match_report
#
# league season team   game
# <NA>   2021   Alavés 2020-12-16 CD Rincón-Alavés       /en/matches/1d1782a2/CD-Rincon-Alaves-December...
#                      2021-01-06 La Coruña-Alavés       /en/matches/74568e06/Deportivo-La-Coruna-Alave...
#                      2021-01-16 Almería-Alavés         /en/matches/a2e544e6/Almeria-Alaves-January-16...
#               Angers 2021-02-11 Angers-Rennes          /en/matches/9c3bef09/Angers-Rennes-February-11...
#                      2021-03-07 Angers-C. Franciscain  /en/matches/884e315e/Angers-C-Franciscain-Marc...
#
# [5 rows x 25 columns]

# %%
fb = sd.FBref(leagues="Big 5 European Leagues Combined", seasons=2021)

team_season_stats = fb.read_team_season_stats(stat_type='standard', opponent_stats=False)
team_match_stats = fb.read_team_match_stats(stat_type='schedule',opponent_stats=False)
team_match_stats.head()

# %%
team_match_stats.head(15)

# %%
current_datetime = datetime.datetime.now()

years = current_datetime.year - 50

for season in range(years, current_datetime.year+1):
    print(season)

# %%
print(team_match_stats.dtypes)

# %%
team_match_stats.head(15)
