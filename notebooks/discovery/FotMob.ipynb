# %%
import soccerdata as sd

FotMob = sd.FotMob()
# Out:
# [08/31/25 18:33:47] INFO     No custom team name replacements found. You can configure these in       ]8;id=789559;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=960378;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_config.py#91\91]8;;\
#                              /home/manati/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=493356;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=377754;file:///home/manati/dataproject/dataenv/lib/python3.12/site-packages/soccerdata/_config.py#197\197]8;;\
#                              /home/manati/soccerdata/config/league_dict.json.
# ...

# %%
FotMob.available_leagues()
# Out:
# ['ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']
